# %%
# %pip install scikit-video
# %pip install seaborn
# %pip install ipywidgets
# %pip install tensorflow
# %pip install kagglehub
# Out:
# Requirement already satisfied: scikit-video in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (1.1.11)
# Requirement already satisfied: numpy in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from scikit-video) (1.24.3)
# Requirement already satisfied: pillow in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from scikit-video) (10.4.0)
# Requirement already satisfied: scipy in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from scikit-video) (1.14.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ipywidgets in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipywidgets) (8.29.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: exceptiongroup in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: colorama in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\gupta\appdata\roaming\python\python310\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\gupta\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tensorflow in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (18.1.1)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.4.0)
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow-intel==2.13.0->tensorflow)
#   Using cached typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.66.1)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.36.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2.2)
# Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
# Successfully installed typing-extensions-4.5.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 8.29.0 requires typing-extensions>=4.6; python_version < "3.12", but you have typing-extensions 4.5.0 which is incompatible.
# openai 1.45.0 requires typing-extensions<5,>=4.11, but you have typing-extensions 4.5.0 which is incompatible.
# paddlepaddle 2.6.1 requires protobuf<=3.20.2,>=3.1.0; platform_system == "Windows", but you have protobuf 3.20.3 which is incompatible.
# pydantic 2.9.1 requires typing-extensions>=4.6.1; python_version < "3.13", but you have typing-extensions 4.5.0 which is incompatible.
# pydantic-core 2.23.3 requires typing-extensions!=4.7.0,>=4.6.0, but you have typing-extensions 4.5.0 which is incompatible.
# python-docx 1.1.2 requires typing-extensions>=4.9.0, but you have typing-extensions 4.5.0 which is incompatible.
# selenium 4.24.0 requires typing_extensions~=4.9, but you have typing-extensions 4.5.0 which is incompatible.
# torch 2.4.1 requires typing-extensions>=4.8.0, but you have typing-extensions 4.5.0 which is incompatible.
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: kagglehub in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (0.3.4)
# Requirement already satisfied: packaging in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from kagglehub) (24.1)
# Requirement already satisfied: requests in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from kagglehub) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from requests->kagglehub) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from requests->kagglehub) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
import skvideo.io  
import os 
import cv2

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import io
import imageio
import ipywidgets
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras import backend as K

# %%
# !git clone https://github.com/seymanurakti/fight-detection-surv-dataset.git
# Out:
# fatal: destination path 'fight-detection-surv-dataset' already exists and is not an empty directory.

# %%
# %pip install --upgrade notebook jupyterlab
# Out:
# Requirement already satisfied: notebook in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (7.2.2)
# Requirement already satisfied: jupyterlab in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (4.2.6)
# Collecting jupyterlab
#   Using cached jupyterlab-4.3.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from notebook) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from notebook) (2.27.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from notebook) (6.4.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab) (0.27.2)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from jupyterlab) (6.29.5)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab) (3.1.4)
# Requirement already satisfied: jupyter-core in c:\users\gupta\appdata\roaming\python\python310\site-packages (from jupyterlab) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab) (2.2.5)
# Requirement already satisfied: packaging in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab) (24.1)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab) (65.5.0)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab) (2.1.0)
# Requirement already satisfied: traitlets in c:\users\gupta\appdata\roaming\python\python310\site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from async-lru>=1.0.0->jupyterlab) (4.5.0)
# Requirement already satisfied: anyio in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.0->jupyterlab) (4.4.0)
# Requirement already satisfied: certifi in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.0->jupyterlab) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.0->jupyterlab) (1.0.5)
# Requirement already satisfied: idna in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.0->jupyterlab) (3.8)
# Requirement already satisfied: sniffio in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.0->jupyterlab) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipykernel>=6.5.0->jupyterlab) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.8.8)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipykernel>=6.5.0->jupyterlab) (8.29.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipykernel>=6.5.0->jupyterlab) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipykernel>=6.5.0->jupyterlab) (6.1.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipykernel>=6.5.0->jupyterlab) (26.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jinja2>=3.0.3->jupyterlab) (2.1.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from jupyter-core->jupyterlab) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from jupyter-core->jupyterlab) (308)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.0.14)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.9.28)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.32.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab) (1.2.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: decorator in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\gupta\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.6.3)
# Collecting typing-extensions>=4.0.0 (from async-lru>=1.0.0->jupyterlab)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: colorama in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab) (2.9.0.post0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (2.2.3)
# Requirement already satisfied: webencodings in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.8.4)
# Requirement already satisfied: fqdn in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (24.11.1)
# Requirement already satisfied: wcwidth in c:\users\gupta\appdata\roaming\python\python310\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\gupta\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\gupta\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.3)
# Requirement already satisfied: pycparser in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.9.0.20241003)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# Successfully installed typing-extensions-4.12.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# paddlepaddle 2.6.1 requires protobuf<=3.20.2,>=3.1.0; platform_system == "Windows", but you have protobuf 3.20.3 which is incompatible.
# tensorflow-intel 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install os
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gupta\appdata\local\programs\python\python310\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for os

# %%
def frame_crop_center(video, cropf):
  f,_,_,_ = video.shape
  startf = f//2 - cropf//2
  return video[startf:startf+cropf, :, :, :]

def load_video_frames(video_path):
  cap = cv2.VideoCapture(video_path)
  if not cap.isOpened():
      return None, None
      
  frames = []
  while cap.isOpened():
      ret, frame = cap.read()
      if not ret:
          break
          
      frame = cv2.resize(frame, (128, 128), interpolation=cv2.INTER_CUBIC)
      frames.append(frame)
  
  cap.release()
  return np.array(frames)

fights = []
nofights = []
surv_fights = []
surv_no_fights = []
video_dims = []

####### Fight data
for filename in os.listdir('Peliculas\\fights'):
  f = os.path.join('Peliculas\\fights', filename)
  video = load_video_frames(f)
  if video is not None:
      video_dims.append(video.shape)
      video = frame_crop_center(video, 42)
      fights.append(video)

for filename in os.listdir('fight-detection-surv-dataset\\fight'):
  f = os.path.join('fight-detection-surv-dataset\\fight', filename)
  video = load_video_frames(f)
  if video is not None:
      video_dims.append(video.shape)
      video = frame_crop_center(video, 42)
      surv_fights.append(video)

####### Non Fight data
for filename in os.listdir('Peliculas\\noFights'):
  f = os.path.join('Peliculas\\noFights', filename)
  video = load_video_frames(f)
  if video is not None:
      video_dims.append(video.shape)
      video = frame_crop_center(video, 42)
      nofights.append(video)

for filename in os.listdir('fight-detection-surv-dataset\\noFight'):
  f = os.path.join('fight-detection-surv-dataset\\noFight', filename)
  video = load_video_frames(f)
  if video is not None:
      video_dims.append(video.shape)
      video = frame_crop_center(video, 42)
      surv_no_fights.append(video)

# %%
data= pd.DataFrame(video_dims, columns=['frame_length', 'height', 'width', 'channels'])
data.describe()
# Out:
#        frame_length  height  width  channels
# count    501.000000   501.0  501.0     501.0
# mean      53.814371   128.0  128.0       3.0
# std       13.348538     0.0    0.0       0.0
# min       20.000000   128.0  128.0       3.0
# 25%       50.000000   128.0  128.0       3.0
# 50%       50.000000   128.0  128.0       3.0
# 75%       60.000000   128.0  128.0       3.0
# max      142.000000   128.0  128.0       3.0

# %%
surv_fights = [video for video in surv_fights if video.shape[0] == 42]
surv_no_fights = [video for video in surv_no_fights if video.shape[0] == 42]

videos = fights + surv_fights + nofights + surv_no_fights
videos = np.asarray(videos)

labels = np.concatenate([np.ones(len(fights)+len(surv_fights)) , np.zeros(len(nofights)+len(surv_no_fights))])

del fights
del nofights
del surv_fights
del surv_no_fights

# %%
X_train, X_test, y_train, y_test = train_test_split(videos, labels, test_size=0.2, random_state=2334)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=124567)

print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (331, 42, 128, 128, 3)
# (37, 42, 128, 128, 3)
# (93, 42, 128, 128, 3)

# %%
# Setting seed for reproducibility
SEED = 77
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"
tf.random.set_seed(SEED)

# DATA
DATASET_NAME = "fight/nofights"
BATCH_SIZE = 4
AUTO = tf.data.AUTOTUNE
INPUT_SHAPE = (42, 128, 128, 3)
NUM_CLASSES = 2

# OPTIMIZER
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-5

# TRAINING
EPOCHS = 20

# TUBELET EMBEDDING
PATCH_SIZE = (8, 8, 8)
NUM_PATCHES = (INPUT_SHAPE[0] // PATCH_SIZE[0]) ** 2

# ViViT ARCHITECTURE
LAYER_NORM_EPS = 1e-6
PROJECTION_DIM = 64
NUM_HEADS = 2
NUM_LAYERS = 2

# %%
@tf.function
def preprocess(frames: tf.Tensor, label: tf.Tensor):
    """Preprocess the frames tensors and parse the labels"""
    # Preprocess images
    frames = tf.image.convert_image_dtype(
        frames[
            ..., tf.newaxis
        ],  # The new axis is to help for further processing with Conv3D layers
        tf.float32,
    )

    # Parse label
    label = tf.cast(label, tf.float32)
    return frames, label


def prepare_dataloader(
    videos: np.ndarray,
    labels: np.ndarray,
    loader_type: str = "train",
    batch_size: int = BATCH_SIZE,
):
    """Utility function to prepare dataloader"""
    dataset = tf.data.Dataset.from_tensor_slices((videos, labels))

    if loader_type == "train":
        dataset = dataset.shuffle(BATCH_SIZE * 2)

    dataloader = (
        dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(batch_size)
        .prefetch(tf.data.AUTOTUNE)
    )

    return dataloader


trainloader = prepare_dataloader(X_train, y_train, "train")
validloader = prepare_dataloader(X_val, y_val, "valid")
testloader = prepare_dataloader(X_test, y_test, "test")

# %%
class TubeletEmbedding(layers.Layer):
    def __init__(self, embed_dim, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.projection = layers.Conv3D(
            filters=embed_dim,
            kernel_size=patch_size,
            strides=patch_size,
            padding="VALID",
        )
        self.flatten = layers.Reshape(target_shape=(-1, embed_dim))

    def call(self, videos):
        projected_patches = self.projection(videos)
        flattened_patches = self.flatten(projected_patches)
        return flattened_patches

class PositionalEncoder(layers.Layer):
    def __init__(self, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim

    def build(self, input_shape):
        _, num_tokens, _ = input_shape
        self.position_embedding = layers.Embedding(
            input_dim=num_tokens, output_dim=self.embed_dim
        )
        self.positions = tf.range(start=0, limit=num_tokens, delta=1)

    def call(self, encoded_tokens):
        # Encode the positions and add it to the encoded tokens
        encoded_positions = self.position_embedding(self.positions)
        encoded_tokens = encoded_tokens + encoded_positions
        return encoded_tokens

# %%
def create_vivit_classifier(
    tubelet_embedder,
    positional_encoder,
    input_shape=INPUT_SHAPE,
    transformer_layers=NUM_LAYERS,
    num_heads=NUM_HEADS,
    embed_dim=PROJECTION_DIM,
    layer_norm_eps=LAYER_NORM_EPS,
    num_classes=NUM_CLASSES,
):
    # Get the input layer
    inputs = layers.Input(shape=input_shape)
    # Create patches.
    patches = tubelet_embedder(inputs)
    # Encode patches.
    encoded_patches = positional_encoder(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization and MHSA
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim // num_heads, dropout=0.1
        )(x1, x1)

        # Skip connection
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer Normalization and MLP
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = keras.Sequential(
            [
                layers.Dense(units=embed_dim * 4, activation=tf.nn.gelu),
                layers.Dense(units=embed_dim, activation=tf.nn.gelu),
            ]
        )(x3)

        # Skip connection
        encoded_patches = layers.Add()([x3, x2])

    # Layer normalization and Global average pooling.
    representation = layers.LayerNormalization(epsilon=layer_norm_eps)(encoded_patches)
    representation = layers.GlobalAvgPool1D()(representation)

    # Classify outputs.
    outputs = layers.Dense(units=num_classes, activation="softmax")(representation)

    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

def run_experiment():
    # Initialize model
    model = create_vivit_classifier(
        tubelet_embedder=TubeletEmbedding(
            embed_dim=PROJECTION_DIM, patch_size=PATCH_SIZE
        ),
        positional_encoder=PositionalEncoder(embed_dim=PROJECTION_DIM),
    )

    # Compile the model with the optimizer, loss function
    # and the metrics.
    optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            recall_m,
            precision_m,
            f1_m,
        ],
    )

    # Train the model.
    _ = model.fit(trainloader, epochs=EPOCHS, validation_data=validloader)

    _, accuracy, recall, precision, f1 = model.evaluate(testloader)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test recall: {round(recall * 100, 2)}%")
    print(f"Test precision: {round(precision * 100, 2)}%")
    print(f"Test F1: {round(f1 * 100, 2)}%")
    
    vivit_scores = [accuracy, recall, precision, f1]
    return model, vivit_scores


model, vivit_scores = run_experiment()

model.save('vivit_model')
# Out:
# Epoch 1/20
# 83/83 [==============================] - 60s 676ms/step - loss: 0.7212 - accuracy: 0.5770 - recall_m: 0.9157 - precision_m: 0.4940 - f1_m: 0.6171 - val_loss: 0.6654 - val_accuracy: 0.5135 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 2/20
# 83/83 [==============================] - 52s 627ms/step - loss: 0.6389 - accuracy: 0.6435 - recall_m: 0.9518 - precision_m: 0.4910 - f1_m: 0.6254 - val_loss: 0.5998 - val_accuracy: 0.6486 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 3/20
# 83/83 [==============================] - 53s 637ms/step - loss: 0.5484 - accuracy: 0.6767 - recall_m: 0.9277 - precision_m: 0.4930 - f1_m: 0.6195 - val_loss: 0.4705 - val_accuracy: 0.7297 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 4/20
# 83/83 [==============================] - 62s 744ms/step - loss: 0.5146 - accuracy: 0.7009 - recall_m: 0.9277 - precision_m: 0.4920 - f1_m: 0.6206 - val_loss: 0.4238 - val_accuracy: 0.8108 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 5/20
# 83/83 [==============================] - 57s 691ms/step - loss: 0.4864 - accuracy: 0.7221 - recall_m: 0.9398 - precision_m: 0.4930 - f1_m: 0.6172 - val_loss: 0.3834 - val_accuracy: 0.8378 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 6/20
# 83/83 [==============================] - 53s 633ms/step - loss: 0.4867 - accuracy: 0.7160 - recall_m: 0.9518 - precision_m: 0.4920 - f1_m: 0.6169 - val_loss: 0.3761 - val_accuracy: 0.8108 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 7/20
# 83/83 [==============================] - 54s 648ms/step - loss: 0.4733 - accuracy: 0.7069 - recall_m: 0.9639 - precision_m: 0.4920 - f1_m: 0.6260 - val_loss: 0.3815 - val_accuracy: 0.7838 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 8/20
# 83/83 [==============================] - 80s 968ms/step - loss: 0.4678 - accuracy: 0.7130 - recall_m: 0.9398 - precision_m: 0.4930 - f1_m: 0.6211 - val_loss: 0.3967 - val_accuracy: 0.7568 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 9/20
# 83/83 [==============================] - 75s 899ms/step - loss: 0.4488 - accuracy: 0.7221 - recall_m: 0.9639 - precision_m: 0.4930 - f1_m: 0.6288 - val_loss: 0.4176 - val_accuracy: 0.8378 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 10/20
# 83/83 [==============================] - 72s 865ms/step - loss: 0.4237 - accuracy: 0.7221 - recall_m: 0.9036 - precision_m: 0.4920 - f1_m: 0.6090 - val_loss: 0.5477 - val_accuracy: 0.8108 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 11/20
# 83/83 [==============================] - 71s 856ms/step - loss: 0.3985 - accuracy: 0.7583 - recall_m: 0.9157 - precision_m: 0.4930 - f1_m: 0.6185 - val_loss: 0.6733 - val_accuracy: 0.6757 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 12/20
# 83/83 [==============================] - 77s 918ms/step - loss: 0.4253 - accuracy: 0.7341 - recall_m: 0.9277 - precision_m: 0.4920 - f1_m: 0.6152 - val_loss: 0.5428 - val_accuracy: 0.7838 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 13/20
# 83/83 [==============================] - 66s 788ms/step - loss: 0.3966 - accuracy: 0.7462 - recall_m: 0.9518 - precision_m: 0.4920 - f1_m: 0.6229 - val_loss: 0.6674 - val_accuracy: 0.7838 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 14/20
# 83/83 [==============================] - 80s 962ms/step - loss: 0.3801 - accuracy: 0.7523 - recall_m: 0.9639 - precision_m: 0.4930 - f1_m: 0.6310 - val_loss: 0.6486 - val_accuracy: 0.7568 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 15/20
# 83/83 [==============================] - 68s 821ms/step - loss: 0.3681 - accuracy: 0.7674 - recall_m: 0.9518 - precision_m: 0.4930 - f1_m: 0.6212 - val_loss: 0.6431 - val_accuracy: 0.8108 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 16/20
# 83/83 [==============================] - 73s 872ms/step - loss: 0.3590 - accuracy: 0.7613 - recall_m: 0.9277 - precision_m: 0.4920 - f1_m: 0.6143 - val_loss: 0.6245 - val_accuracy: 0.8108 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 17/20
# 83/83 [==============================] - 74s 892ms/step - loss: 0.3510 - accuracy: 0.7644 - recall_m: 0.9398 - precision_m: 0.4920 - f1_m: 0.6189 - val_loss: 0.5853 - val_accuracy: 0.7838 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 18/20
# 83/83 [==============================] - 88s 1s/step - loss: 0.3435 - accuracy: 0.7795 - recall_m: 0.9518 - precision_m: 0.4920 - f1_m: 0.6178 - val_loss: 0.6496 - val_accuracy: 0.7838 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 19/20
# 83/83 [==============================] - 84s 1s/step - loss: 0.3463 - accuracy: 0.7764 - recall_m: 0.9277 - precision_m: 0.4910 - f1_m: 0.6116 - val_loss: 0.6026 - val_accuracy: 0.7297 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# Epoch 20/20
# 83/83 [==============================] - 75s 897ms/step - loss: 0.3655 - accuracy: 0.7674 - recall_m: 0.8675 - precision_m: 0.4920 - f1_m: 0.6092 - val_loss: 0.4626 - val_accuracy: 0.7838 - val_recall_m: 0.9000 - val_precision_m: 0.4750 - val_f1_m: 0.6038
# 24/24 [==============================] - 9s 367ms/step - loss: 0.5648 - accuracy: 0.6129 - recall_m: 0.9583 - precision_m: 0.6146 - f1_m: 0.7310
# Test accuracy: 61.29%
# Test recall: 95.83%
# Test precision: 61.46%
# Test F1: 73.1%
# INFO:tensorflow:Assets written to: vivit_model\assets
# INFO:tensorflow:Assets written to: vivit_model\assets

# %%
y_preds = np.argmax(model.predict(testloader), axis=1)

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_preds)

ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues')

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

## Display the visualization of the Confusion Matrix.
plt.show()
ax.figure.savefig("vivit_cf.png")
# Out:
# 24/24 [==============================] - 9s 336ms/step

# %%
NUM_SAMPLES_VIZ = 25

testsamples, labels_ = next(iter(testloader))
testsamples, labels_ = X_test[:NUM_SAMPLES_VIZ], y_test[:NUM_SAMPLES_VIZ]

ground_truths = []
preds = []
videos_ = []

for i, (testsample, label) in enumerate(zip(testsamples, labels_)):
    # Generate gif
    with io.BytesIO() as gif:
        imageio.mimsave(gif, (testsample * 255).astype("uint8"), "GIF", fps=5)
        videos_.append(gif.getvalue())

    # Get model prediction
    output = model.predict(tf.expand_dims(testsample, axis=0))[0]
    pred = np.argmax(output, axis=0)

    ground_truths.append(label.astype("int"))
    preds.append(pred)


def make_box_for_grid(image_widget, fit):
    """Make a VBox to hold caption/image for demonstrating option_fit values.

    Source: https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20Styling.html
    """
    # Make the caption
    if fit is not None:
        fit_str = "'{}'".format(fit)
    else:
        fit_str = str(fit)

    h = ipywidgets.HTML(value="" + str(fit_str) + "")

    # Make the green box with the image widget inside it
    boxb = ipywidgets.widgets.Box()
    boxb.children = [image_widget]

    # Compose into a vertical box
    vb = ipywidgets.widgets.VBox()
    vb.layout.align_items = "center"
    vb.children = [h, boxb]
    return vb


boxes = []
label_dict = {0: 'noFight', 1: 'Fight'}
for i in range(NUM_SAMPLES_VIZ):
    ib = ipywidgets.widgets.Image(value=videos_[i], width=200, height=200)
    true_class = label_dict[ground_truths[i]]
    pred_class = label_dict[preds[i]]
    caption = f"T: {true_class} | P: {pred_class}"

    boxes.append(make_box_for_grid(ib, caption))

ipywidgets.widgets.GridBox(
    boxes, layout=ipywidgets.widgets.Layout(grid_template_columns="repeat(5, 200px)")
)
# Out:
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 94ms/step
# GridBox(children=(VBox(children=(HTML(value="'T: Fight | P: noFight'"), Box(children=(Image(value=b'GIF89a\x80…
